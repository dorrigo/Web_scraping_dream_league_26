# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('dota2_dream_league_26.csv')
print(dataset.head())
# Out:
#                  Hero  Picks Win Rate  Bans Contest Rate
# 0    Templar Assassin     22   81.82%   152       92.55%
# 1         Bristleback     37   64.86%   141       94.68%
# 2           Dark Seer     35      60%   122       83.51%
# 3         Beastmaster     29   41.38%   120       79.26%
# 4  Ancient Apparition     47   51.06%    97       76.60%

# %%
# Mostra os heróis mais pickados
data_pick = dataset.sort_values(by='Picks', ascending=False).head(5)[['Hero', 'Picks']]

# Cria o gráfico de barras com os 5 heróis mais pickados
sns.barplot(x='Picks', y='Hero', data=data_pick, palette='viridis', edgecolor='black')
plt.title('Top 5 Heróis mais Pickados')
for i, (hero, picks) in enumerate(zip(data_pick['Hero'], data_pick['Picks'])):
    plt.text(picks + 1, i, str(picks), va='center')
plt.figure(figsize=(10, 6))
plt.show()
# Out:
# C:\Users\dorri\AppData\Local\Temp\ipykernel_20516\3678964489.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Picks', y='Hero', data=data_pick, palette='viridis', edgecolor='black')

# %%
# Define dataset para os 5 heróis mais banidos
data_ban = dataset.sort_values(by='Bans', ascending=False).head(5)[['Hero', 'Bans']]

# Cria o gráfico de barras para os 5 heróis mais banidos
sns.barplot(x='Bans', y='Hero', data=data_ban, palette='rocket', edgecolor='black')
plt.title('Top 5 Heróis mais Banidos')
for i, (hero, bans) in enumerate(zip(data_ban['Hero'], data_ban['Bans'])):
    plt.text(bans + 1, i, str(bans), va='center')
plt.figure(figsize=(10, 6))
plt.show()
# Out:
#                  Hero  Bans
# 0    Templar Assassin   152
# 1         Bristleback   141
# 2           Dark Seer   122
# 3         Beastmaster   120
# 4  Ancient Apparition    97
# C:\Users\dorri\AppData\Local\Temp\ipykernel_20516\1890060772.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Bans', y='Hero', data=data_ban, palette='rocket', edgecolor='black')

# %%
# Filtra heróis com pelo menos 10 picks e ordena pelo maior win rate
winrate_10picks = dataset_filtered[dataset_filtered['Picks'] >= 10].sort_values(by='Win Rate (%)', ascending=False)

# Plota o gráfico de barras dos 5 heróis com maior win rate (pelo menos 10 picks)
top5_winrate = winrate_10picks.head(5)
sns.barplot(x='Win Rate (%)', y='Hero', data=top5_winrate, palette='crest', edgecolor='black')
plt.title('Heróis com Maior Win Rate (pelo menos 10 jogos)')
for i, (win_rate, hero) in enumerate(zip(top5_winrate['Win Rate (%)'], top5_winrate['Hero'])):
    plt.text(win_rate + 1, i, f"{win_rate:.2f}%", va='center')
plt.figure(figsize=(10, 6))
plt.show()
# Out:
# C:\Users\dorri\AppData\Local\Temp\ipykernel_20516\569388719.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Win Rate (%)', y='Hero', data=top5_winrate, palette='crest', edgecolor='black')

# %%
# Plota os heróis com pior win rate (pelo menos 10 jogos)
sns.barplot(x='Win Rate (%)', y='Hero', data=pior5_winrate, palette='magma', edgecolor='black')
plt.title('Heróis com pior win rate (pelo menos 10 jogos)')
for i, (win_rate, hero) in enumerate(zip(pior5_winrate['Win Rate (%)'], pior5_winrate['Hero'])):
    plt.text(win_rate + 1, i, f"{win_rate:.2f}%", va='center')
plt.figure(figsize=(10, 6))
plt.show()
# Out:
# C:\Users\dorri\AppData\Local\Temp\ipykernel_20516\2684632359.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Win Rate (%)', y='Hero', data=pior5_winrate, palette='magma', edgecolor='black')

# %%
# Out:
# Total de heróis: 100
